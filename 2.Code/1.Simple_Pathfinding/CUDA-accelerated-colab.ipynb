# %% [markdown]
# # CUDA Acceleration
#
# Here we will use CUDA to parallelize the computation of our swarm of ants. This Jupyter notebook is to be run on a CUDA enabled machine. As a result, if you have a mac, a PC without NVIDIA graphics, or not setup CUDA, the wuickest way to run is through Google Collab.
#
# *Look at [this](https://stackoverflow.com/questions/50560395/how-to-install-cuda-in-google-colab-gpus) to enable CUDA in Google Colab.*
#
# Here we will run multiple nodes of our swarm and see how they traverse different environments. It is the same thing as in the other notebooks only here we do it for much larger numbers.

# %%
# Check if GPU is Running
# !nvidia-smi
# Out:
# Thu Jul 22 16:45:46 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# Import necessary libraries
import numba
import numpy as np
from timeit import default_timer as timer

@numba.vectorize(['float32(float32,float32)'],target='cuda')
def add(a,b):
  return a+b

def main():
  N = int(1e9)

  A = np.ones(N,dtype=np.float32)
  B = np.ones(N,dtype=np.float32)
  C = np.zeros(N,dtype=np.float32)

  start=timer()
  C = add(A,B)
  time = timer()-start

  print(C)
  print(time)

main()

# %%
1e-4
# Out:
# 0.0001
